# %%
import pandas as pd

# %%
url = "https://storage.cloud.google.com/lloyds-genai24lon-2701-bucket/decisions_2023.csv"
df = pd.read_csv(url, on_bad_lines='skip')

# %%
df.head
# Out:
# <bound method NDFrame.head of                                                                                                                                                                                                                                                                                                                                                                                     <!doctype html><html lang="en-US" dir="ltr"><head><base href="https://accounts.google.com/v3/signin/"><meta name="referrer" content="origin"><style data-href="https://www.gstatic.com/_/mss/boq-identity/_/ss/k=boq-identity.AccountsSignInUi.pZfLwHMOVrY.L.X.O/am=P8ASHY4FoAAIBA0AIABQAAAAAAAAAAAANIAlBA/d=1/ed=1/rs=AOaEmlFcwNg-Zso5f89WQSZVN-3ggk_8xA/m=identifierview  \
# ...
