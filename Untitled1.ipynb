# %%
import os
import pandas as pd
import pickle


PROJECT_ID = os.getenv("GOOGLE_CLOUD_PROJECT")
LOCATION = "europe-west1"
BUCKET_NAME = "lloyds-genai24lon-2701-bucket"

# %%
# !pip install gcsfs

# %%
max_len = None
df = pd.read_csv(f'gs://{BUCKET_NAME}/summaries/fos_summary_1.csv')

print(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/.venv/lib/python3.10/site-packages/fsspec/registry.py:236, in get_filesystem_class(protocol)
#     235 try:
# --> 236     register_implementation(protocol, _import_class(bit["class"]))
#     237 except ImportError as e:
#
# File ~/.venv/lib/python3.10/site-packages/fsspec/registry.py:271, in _import_class(cls, minv)
#     270 s3 = mod == "s3fs"
# --> 271 mod = importlib.import_module(mod)
#     272 if s3 and mod.__version__.split(".") < ["0", "5"]:
#
# File /opt/conda/lib/python3.10/importlib/__init__.py:126, in import_module(name, package)
#     125         level += 1
# --> 126 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1050, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1027, in _find_and_load(name, import_)
#
# ...
